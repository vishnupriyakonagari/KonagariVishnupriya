# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriyakonagari/KonagariVishnupriya/blob/main/MinorProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread # This normalizes the pixel values
from skimage.transform import resize
 
# Opencv - BGR2GRAY
# Skimage = rgb2gray

# %%
# Curse of Dimensionality : If number of features are more, then accuracy reduces

# %%
# Displaying the image
path = '/content/drive/MyDrive/AI/Images/Bikes/Ultraviolette-f77-electric-bike-660x440.jpg'
img = plt.imread(path)
plt.imshow(img)
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
img.shape
# Out:
# (440, 660, 3)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

datadir = '/content/drive/MyDrive/AI/Images'

categories = ['Bikes','Cars'] # Name the folder with these categories
target = []
flat_data = []

for i in categories:
  path = os.path.join(datadir,i)
  #print(path)
  for img in os.listdir(path):
    print(img)
    img_array = imread(os.path.join(path,img))

    img_resize = resize(img_array,(150,150,3)) # Value gets converted 0-1 from 0-255
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)
    plt.imshow(img_resize)
    plt.show()

flat_data = np.array(flat_data)
target = np.array(target)
# Out:
# Ultraviolette-f77-electric-bike-660x440.jpg
# um-renegade-commando-1068x801.jpg
# 960x0.jpg
# SONATA-hero-option1-764A5360-edit.jpg
# Transpo_G70_TA-518126.jpg
# bugatti-chiron-pur-sport-106-1582836604.jpg
# ferrari_f8_tributo.jpg
# future-cars-lead.jpg
# SeltosModelImage.jpg
# download.jpg
# download (1).jpg
# 1-corvette-stingray-c8-2019-fd-hr-hero-front_0.jpg

# %%
from skimage.color import rgb2gray

img_resize = resize(img_array,(50,50))
img_gray = rgb2gray(img_resize)
plt.imshow(img_gray,cmap='gray')
img_gray.size

# Further Study : Image Features Extraction, HOG Extraction
# Out:
# 2500

# %%
df = pd.DataFrame(flat_data)
df['Target'] = target
df
# Out:
#            0         1         2  ...     67498     67499  Target
# 0   0.996078  0.996078  0.996078  ...  0.996078  0.996078   Bikes
# 1   0.972549  0.933333  0.886275  ...  0.392392  0.384354   Bikes
# 2   0.075686  0.063922  0.091373  ...  0.109059  0.124745    Cars
# 3   0.874510  0.827529  0.796078  ...  0.360784  0.462837    Cars
# 4   0.488523  0.764706  0.894118  ...  0.568627  0.474797    Cars
# 5   0.121569  0.494118  0.619608  ...  0.270353  0.231137    Cars
# 6   0.430523  0.427556  0.417752  ...  0.486275  0.443137    Cars
# 7   0.273765  0.313725  0.329412  ...  0.070588  0.070588    Cars
# 8   0.992157  0.992157  0.992157  ...  1.000000  1.000000    Cars
# 9   0.011674  0.050561  0.023072  ...  0.154222  0.222314    Cars
# 10  0.937778  0.965490  0.962614  ...  0.958039  0.955556    Cars
# 11  0.717647  0.717647  0.717647  ...  0.317647  0.305882    Cars
#
# [12 rows x 67501 columns]

# %%
# dtype - uint16

# 0 - 255 ( Standard )
# 0 - 65535

# %%
# 3 sessions
# Text Data 
# Encoding Techniques : COunt and TFIDF
# Case Study
# Web app Creation using Streamlit
# Deploying the webAPp on Heroku CLoud Platform

# Create an account on Github and Heroku

# Major project : Sentiment Analysis(text)
